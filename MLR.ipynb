# %% [markdown]
# <a href="https://colab.research.google.com/github/bshriselvamkumar/AI-ML-DL-Training/blob/main/MLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e61b39b5-a9f7-4777-98a6-a1e7320d7a57" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e61b39b5-a9f7-4777-98a6-a1e7320d7a57">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# #Data Pre-Processing...

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %% [markdown]
# #Data Cleaning.......

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# #Feature Selection.........

# %%
df = df.drop(columns=['Row ID','Order ID'])

# %%
df
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID     Customer Name  \
# 0     08/11/2017  11/11/2017    Second Class    CG-12520       Claire Gute
# 1     08/11/2017  11/11/2017    Second Class    CG-12520       Claire Gute
# 2     12/06/2017  16/06/2017    Second Class    DV-13045   Darrin Van Huff
# 3     11/10/2016  18/10/2016  Standard Class    SO-20335    Sean O'Donnell
# 4     11/10/2016  18/10/2016  Standard Class    SO-20335    Sean O'Donnell
# ...          ...         ...             ...         ...               ...
# 9795  21/05/2017  28/05/2017  Standard Class    SH-19975     Sally Hughsby
# 9796  12/01/2016  17/01/2016  Standard Class    CS-12490  Cindy Schnelling
# 9797  12/01/2016  17/01/2016  Standard Class    CS-12490  Cindy Schnelling
# 9798  12/01/2016  17/01/2016  Standard Class    CS-12490  Cindy Schnelling
# 9799  12/01/2016  17/01/2016  Standard Class    CS-12490  Cindy Schnelling
#
# ...

# %%
columns_drop = [0,1,3,4,5,6,7,9,10,11]
df = df.drop(df.columns[columns_drop],axis=1)

# %%
df
# Out:
#            Ship Mode       State         Category Sub-Category  \
# 0       Second Class    Kentucky        Furniture    Bookcases
# 1       Second Class    Kentucky        Furniture       Chairs
# 2       Second Class  California  Office Supplies       Labels
# 3     Standard Class     Florida        Furniture       Tables
# 4     Standard Class     Florida  Office Supplies      Storage
# ...              ...         ...              ...          ...
# 9795  Standard Class    Illinois  Office Supplies      Binders
# 9796  Standard Class        Ohio  Office Supplies          Art
# 9797  Standard Class        Ohio       Technology       Phones
# 9798  Standard Class        Ohio       Technology       Phones
# 9799  Standard Class        Ohio       Technology  Accessories
#
#                                            Product Name     Sales
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# ...

# %%
columns_drop1 = [4]
df = df.drop(df.columns[columns_drop1],axis=1)

# %%
df
# Out:
#            Ship Mode       State         Category Sub-Category     Sales
# 0       Second Class    Kentucky        Furniture    Bookcases  261.9600
# 1       Second Class    Kentucky        Furniture       Chairs  731.9400
# 2       Second Class  California  Office Supplies       Labels   14.6200
# 3     Standard Class     Florida        Furniture       Tables  957.5775
# 4     Standard Class     Florida  Office Supplies      Storage   22.3680
# ...              ...         ...              ...          ...       ...
# 9795  Standard Class    Illinois  Office Supplies      Binders    3.7980
# 9796  Standard Class        Ohio  Office Supplies          Art   10.3680
# 9797  Standard Class        Ohio       Technology       Phones  235.1880
# 9798  Standard Class        Ohio       Technology       Phones   26.3760
# 9799  Standard Class        Ohio       Technology  Accessories   10.3840
#
# [9800 rows x 5 columns]

# %% [markdown]
# #Data Encoding...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
#df1['ocean_proximity'] = le.fit_transform(df1['ocean_proximity'])
df['Ship Mode'] = le.fit_transform(df['Ship Mode'])

# %%
df
# Out:
#       Ship Mode       State         Category Sub-Category     Sales
# 0             2    Kentucky        Furniture    Bookcases  261.9600
# 1             2    Kentucky        Furniture       Chairs  731.9400
# 2             2  California  Office Supplies       Labels   14.6200
# 3             3     Florida        Furniture       Tables  957.5775
# 4             3     Florida  Office Supplies      Storage   22.3680
# ...         ...         ...              ...          ...       ...
# 9795          3    Illinois  Office Supplies      Binders    3.7980
# 9796          3        Ohio  Office Supplies          Art   10.3680
# 9797          3        Ohio       Technology       Phones  235.1880
# 9798          3        Ohio       Technology       Phones   26.3760
# 9799          3        Ohio       Technology  Accessories   10.3840
#
# [9800 rows x 5 columns]

# %%
df['State'] = le.fit_transform(df['State'])

# %%
df['Category'] = le.fit_transform(df['Category'])

# %%
df['Sub-Category'] = le.fit_transform(df['Sub-Category'])

# %%
df
# Out:
#       Ship Mode  State  Category  Sub-Category     Sales
# 0             2     15         0             4  261.9600
# 1             2     15         0             5  731.9400
# 2             2      3         1            10   14.6200
# 3             3      8         0            16  957.5775
# 4             3      8         1            14   22.3680
# ...         ...    ...       ...           ...       ...
# 9795          3     11         1             3    3.7980
# 9796          3     33         1             2   10.3680
# 9797          3     33         2            13  235.1880
# 9798          3     33         2            13   26.3760
# 9799          3     33         2             0   10.3840
#
# [9800 rows x 5 columns]

# %% [markdown]
# x,y split

# %%
x=df.iloc[:,0:4]

# %%
x
# Out:
#       Ship Mode  State  Category  Sub-Category
# 0             2     15         0             4
# 1             2     15         0             5
# 2             2      3         1            10
# 3             3      8         0            16
# 4             3      8         1            14
# ...         ...    ...       ...           ...
# 9795          3     11         1             3
# 9796          3     33         1             2
# 9797          3     33         2            13
# 9798          3     33         2            13
# 9799          3     33         2             0
#
# [9800 rows x 4 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9795      3.7980
# 9796     10.3680
# 9797    235.1880
# 9798     26.3760
# 9799     10.3840
# Name: Sales, Length: 9800, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 1234)

# %%
x_train.shape
# Out:
# (7840, 4)

# %%
x_test.shape
# Out:
# (1960, 4)

# %% [markdown]
# #Model building....

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x_test)

# %% [markdown]
# #evaluation....

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
MAE = mean_absolute_error(y_test,y_predict)

# %%
MSE = mean_squared_error(y_test,y_predict)

# %%
RMSE = np.sqrt(MSE)

# %%
MAE
# Out:
# 268.6757248382533

# %%
MSE
# Out:
# 362121.7827465887

# %%
R2 = r2_score(y_test,y_predict)

# %%
R2 #coeffiency of determination
# Out:
# 0.00598875569294588
