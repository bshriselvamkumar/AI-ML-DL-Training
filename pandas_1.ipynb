# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-c3a952fd-0d46-438a-a141-88ab17e31756" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3a952fd-0d46-438a-a141-88ab17e31756">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data
# Out:
# {'oil-company-doe.csv': b'x1,x2,x3,x4,y\r\n4.38,1.6,No,2.18,28.03\r\n6.2,2.26,null,2.18,37.25\r\n6.2,2.26,Yes,2.18,37.22\r\nnull,2.26,Yes,3.08,37.06\r\n6.2,1.6,null,3.08,39.23\r\n6.2,1.6,No,3.08,30.86\r\n6.2,1.6,No,3.08,null\r\n6.2,1.6,Yes,3.08,39.21\r\n4.38,2.26,No,3.08,29.31\r\n4.38,2.26,Yes,3.08,37.03\r\n4.38,null,No,3.08,null\r\n6.2,2.26,No,null,34.63\r\n5.6,2.26,No,2.78,29.73\r\n6.2,1.82,Yes,2.48,37.89\r\n6.2,2.04,No,2.18,31.71\r\n5.6,1.6,No,2.18,29\r\n4.98,1.6,Yes,null,36.15\r\n5.6,2.26,No,2.78,29.77\r\nnull,2.04,No,2.18,29.4\r\n'}

# %%
df = pd.read_csv('oil-company-doe.csv')

# %%
df
# Out:
#       x1    x2   x3    x4      y
# 0   4.38  1.60   No  2.18  28.03
# 1   6.20  2.26  NaN  2.18  37.25
# 2   6.20  2.26  Yes  2.18  37.22
# 3    NaN  2.26  Yes  3.08  37.06
# 4   6.20  1.60  NaN  3.08  39.23
# 5   6.20  1.60   No  3.08  30.86
# 6   6.20  1.60   No  3.08    NaN
# 7   6.20  1.60  Yes  3.08  39.21
# 8   4.38  2.26   No  3.08  29.31
# 9   4.38  2.26  Yes  3.08  37.03
# 10  4.38   NaN   No  3.08    NaN
# 11  6.20  2.26   No   NaN  34.63
# 12  5.60  2.26   No  2.78  29.73
# 13  6.20  1.82  Yes  2.48  37.89
# 14  6.20  2.04   No  2.18  31.71
# 15  5.60  1.60   No  2.18  29.00
# 16  4.98  1.60  Yes   NaN  36.15
# 17  5.60  2.26   No  2.78  29.77
# 18   NaN  2.04   No  2.18  29.40

# %%
df # dataframe
# Out:
#       x1    x2   x3    x4      y
# 0   4.38  1.60   No  2.18  28.03
# 1   6.20  2.26  NaN  2.18  37.25
# 2   6.20  2.26  Yes  2.18  37.22
# 3    NaN  2.26  Yes  3.08  37.06
# 4   6.20  1.60  NaN  3.08  39.23
# 5   6.20  1.60   No  3.08  30.86
# 6   6.20  1.60   No  3.08    NaN
# 7   6.20  1.60  Yes  3.08  39.21
# 8   4.38  2.26   No  3.08  29.31
# 9   4.38  2.26  Yes  3.08  37.03
# 10  4.38   NaN   No  3.08    NaN
# 11  6.20  2.26   No   NaN  34.63
# 12  5.60  2.26   No  2.78  29.73
# 13  6.20  1.82  Yes  2.48  37.89
# 14  6.20  2.04   No  2.18  31.71
# 15  5.60  1.60   No  2.18  29.00
# 16  4.98  1.60  Yes   NaN  36.15
# 17  5.60  2.26   No  2.78  29.77
# 18   NaN  2.04   No  2.18  29.40

# %%
df.shape
# Out:
# (19, 5)

# %%
df.head(7)
# Out:
#      x1    x2   x3    x4      y
# 0  4.38  1.60   No  2.18  28.03
# 1  6.20  2.26  NaN  2.18  37.25
# 2  6.20  2.26  Yes  2.18  37.22
# 3   NaN  2.26  Yes  3.08  37.06
# 4  6.20  1.60  NaN  3.08  39.23
# 5  6.20  1.60   No  3.08  30.86
# 6  6.20  1.60   No  3.08    NaN

# %%
df.tail(3)
# Out:
#       x1    x2   x3    x4      y
# 16  4.98  1.60  Yes   NaN  36.15
# 17  5.60  2.26   No  2.78  29.77
# 18   NaN  2.04   No  2.18  29.40

# %%
df.sample(5)
# Out:
#      x1    x2   x3    x4      y
# 1   6.2  2.26  NaN  2.18  37.25
# 6   6.2  1.60   No  3.08    NaN
# 3   NaN  2.26  Yes  3.08  37.06
# 4   6.2  1.60  NaN  3.08  39.23
# 12  5.6  2.26   No  2.78  29.73

# %%
df.info() # technical enquiry
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      17 non-null     float64
#  1   x2      18 non-null     float64
#  2   x3      17 non-null     object
#  3   x4      17 non-null     float64
#  4   y       17 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 888.0+ bytes

# %%
df.columns
# Out:
# Index(['x1', 'x2', 'x3', 'x4', 'y'], dtype='object')

# %%
df.describe()
# Out:
#               x1         x2         x4          y
# count  17.000000  18.000000  17.000000  17.000000
# mean    5.594118   1.954444   2.691765  33.734118
# std     0.773685   0.312395   0.421133   4.092284
# min     4.380000   1.600000   2.180000  28.030000
# 25%     4.980000   1.600000   2.180000  29.730000
# 50%     6.200000   2.040000   2.780000  34.630000
# 75%     6.200000   2.260000   3.080000  37.220000
# max     6.200000   2.260000   3.080000  39.230000
